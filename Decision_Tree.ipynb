# %% [markdown]
# <a href="https://colab.research.google.com/github/KeshavaOfficial/keshav/blob/Projects/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/heart_disease.csv')

# %%
df.head()
# Out:
#    age   sex               cp  trestbps  chol    fbs         restecg  thalch  \
# 0   63  Male   typical angina       145   233   True  lv hypertrophy     150
# 1   41  Male  atypical angina       135   203  False          normal     132
# 2   57  Male     asymptomatic       140   192  False          normal     148
# 3   52  Male   typical angina       118   186  False  lv hypertrophy     190
# 4   57  Male     asymptomatic       110   201  False          normal     126
#
#    exang  oldpeak        slope          thal  num
# 0  FALSE      2.3  downsloping  fixed defect    0
# 1  FALSE      0.0         flat  fixed defect    0
# 2  FALSE      0.4         flat  fixed defect    0
# 3  FALSE      0.0         flat  fixed defect    0
# 4   TRUE      1.5         flat  fixed defect    0

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalch       0
# exang        0
# oldpeak     62
# slope        0
# thal         0
# num          0
# dtype: int64

# %%
df.describe()
# Out:
#               age    trestbps        chol      thalch     oldpeak         num
# count  908.000000  908.000000  908.000000  908.000000  846.000000  908.000000
# mean    53.791850  133.430617  201.484581  135.957048    0.891253    1.008811
# std      9.158031   20.401608  112.097949   26.804929    1.093875    1.144436
# min     29.000000    0.000000    0.000000   60.000000   -2.600000    0.000000
# 25%     47.750000  120.000000  176.750000  118.000000    0.000000    0.000000
# 50%     54.000000  130.000000  224.000000  138.000000    0.500000    1.000000
# 75%     60.000000  144.000000  270.000000  156.000000    1.500000    2.000000
# max     77.000000  200.000000  603.000000  202.000000    6.200000    4.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       908 non-null    int64
#  1   sex       908 non-null    object
#  2   cp        908 non-null    object
#  3   trestbps  908 non-null    int64
#  4   chol      908 non-null    int64
#  5   fbs       908 non-null    bool
#  6   restecg   908 non-null    object
#  7   thalch    908 non-null    int64
#  8   exang     908 non-null    object
#  9   oldpeak   846 non-null    float64
#  10  slope     908 non-null    object
#  11  thal      908 non-null    object
#  12  num       908 non-null    int64
# dtypes: bool(1), float64(1), int64(5), object(6)
# memory usage: 86.1+ KB

# %%
df_num = df.sort_values(by=['num'], ascending=False)
df_num
# Out:
#      age     sex               cp  trestbps  chol    fbs           restecg  \
# 886   65  Female     asymptomatic       150   225  False    lv hypertrophy
# 907   57    Male     asymptomatic       142   277   True  st-t abnormality
# 906   56    Male      non-anginal       144   208   True  st-t abnormality
# 905   56    Male      non-anginal       170     0  False    lv hypertrophy
# 904   62    Male     asymptomatic       166   170  False  st-t abnormality
# ..   ...     ...              ...       ...   ...    ...               ...
# 393   54    Male  atypical angina        96   182  False  st-t abnormality
# 392   63    Male  atypical angina        90   165  False  st-t abnormality
# 391   35    Male      non-anginal       143   161  False  st-t abnormality
# 390   62    Male   typical angina       134   139  False  st-t abnormality
# 21    64  Female     asymptomatic       130   303  False            normal
#
#      thalch  exang  oldpeak        slope               thal  num
# 886     114  FALSE      1.0         flat  reversable defect    4
# 907     182  FALSE      NaN         flat       fixed defect    4
# 906     105   TURE      NaN  downsloping  reversable defect    4
# 905     123   TRUE      2.5  downsloping             normal    4
# 904     120   TRUE      3.0         flat       fixed defect    4
# ..      ...    ...      ...          ...                ...  ...
# 393     103   TURE      NaN    upsloping  reversable defect    0
# 392     178  FALSE      NaN  downsloping       fixed defect    0
# 391      81  FALSE      NaN    upsloping             normal    0
# 390      96   TURE      NaN         flat       fixed defect    0
# 21      122  FALSE      2.0         flat             normal    0
#
# [908 rows x 13 columns]

# %%
x = df.iloc[:, 0:12]

# %%
y = df['num']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 903    4
# 904    4
# 905    4
# 906    4
# 907    4
# Name: num, Length: 908, dtype: int64

# %%
x
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal
# 0       150  FALSE      2.3  downsloping       fixed defect
# 1       132  FALSE      0.0         flat       fixed defect
# 2       148  FALSE      0.4         flat       fixed defect
# 3       190  FALSE      0.0         flat       fixed defect
# 4       126   TRUE      1.5         flat       fixed defect
# ..      ...    ...      ...          ...                ...
# 903     120  FALSE      1.5    upsloping       fixed defect
# 904     120   TRUE      3.0         flat       fixed defect
# 905     123   TRUE      2.5  downsloping             normal
# 906     105   TURE      NaN  downsloping  reversable defect
# 907     182  FALSE      NaN         flat       fixed defect
#
# [908 rows x 12 columns]

# %%
x.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalch',
#        'exang', 'oldpeak', 'slope', 'thal'],
#       dtype='object')

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: num, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit_transform(x['sex'])
x['sex'] = le.fit_transform(x['sex'])

# %%
le.fit_transform(x['cp'])
x['cp'] = le.fit_transform(x['cp'])

# %%
le.fit_transform(x['fbs'])
x['fbs'] = le.fit_transform(x['fbs'])

# %%
le.fit_transform(x['restecg'])
x['restecg'] = le.fit_transform(x['restecg'])

# %%
le.fit_transform(x['exang'])
x['exang'] = le.fit_transform(x['exang'])

# %%
le.fit_transform(x['slope'])
x['slope'] = le.fit_transform(x['slope'])

# %%
le.fit_transform(x['thal'])
x['thal'] = le.fit_transform(x['thal'])

# %%
x.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalch       0
# exang        0
# oldpeak     62
# slope        0
# thal         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
imputer.fit(x[['oldpeak']])
x[['oldpeak']] = imputer.transform(x[['oldpeak']])

# %%
x.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# thal        0
# dtype: int64

# %%
x.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.052194 -0.067589  0.253999 -0.099967  0.176702
# sex       0.052194  1.000000 -0.125130  0.016441 -0.191513  0.092167
# cp       -0.067589 -0.125130  1.000000  0.009078  0.071160 -0.045228
# trestbps  0.253999  0.016441  0.009078  1.000000  0.117488  0.111614
# chol     -0.099967 -0.191513  0.071160  0.117488  1.000000 -0.113721
# fbs       0.176702  0.092167 -0.045228  0.111614 -0.113721  1.000000
# restecg  -0.007518  0.078158 -0.072048  0.058148 -0.194473  0.067320
# thalch   -0.328088 -0.178794  0.248211 -0.133360  0.197907 -0.065428
# exang     0.210074  0.192197 -0.287621  0.182705 -0.029853  0.060590
# oldpeak   0.232718  0.101209 -0.170467  0.152162  0.028744  0.022756
# slope    -0.054644 -0.045065  0.092177  0.006748  0.047292 -0.026636
# thal      0.049875  0.052589 -0.035644  0.033738  0.009640  0.012954
#
#            restecg    thalch     exang   oldpeak     slope      thal
# age      -0.007518 -0.328088  0.210074  0.232718 -0.054644  0.049875
# sex       0.078158 -0.178794  0.192197  0.101209 -0.045065  0.052589
# cp       -0.072048  0.248211 -0.287621 -0.170467  0.092177 -0.035644
# trestbps  0.058148 -0.133360  0.182705  0.152162  0.006748  0.033738
# chol     -0.194473  0.197907 -0.029853  0.028744  0.047292  0.009640
# fbs       0.067320 -0.065428  0.060590  0.022756 -0.026636  0.012954
# restecg   1.000000 -0.195198  0.126247 -0.031561 -0.084796 -0.149155
# thalch   -0.195198  1.000000 -0.359351 -0.128728  0.224048 -0.031230
# exang     0.126247 -0.359351  1.000000  0.318034 -0.149261  0.060492
# oldpeak  -0.031561 -0.128728  0.318034  1.000000 -0.184895  0.086583
# slope    -0.084796  0.224048 -0.149261 -0.184895  1.000000 -0.029945
# thal     -0.149155 -0.031230  0.060492  0.086583 -0.029945  1.000000

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', max_depth= 3 )
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
y_pred = model.predict(x_test)

# %%
tree.plot_tree(model);

# %%
x.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalch',
#        'exang', 'oldpeak', 'slope', 'thal'],
#       dtype='object')

# %%
fn = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca']
cn = ['No heart attack', 'Stage 1', 'Stage 2', 'Stage 3', 'stage 4' ]
tree.plot_tree(model,
               feature_names = fn,
               class_names=cn,
               filled = True);

# %%
text = tree.export_text(model,max_depth=3)
print(text)
# Out:
# |--- feature_2 <= 0.50
# |   |--- feature_9 <= 1.75
# |   |   |--- feature_4 <= 42.50
# |   |   |   |--- class: 1
# |   |   |--- feature_4 >  42.50
# |   |   |   |--- class: 1
# |   |--- feature_9 >  1.75
# |   |   |--- feature_0 <= 58.50
# |   |   |   |--- class: 1
# |   |   |--- feature_0 >  58.50
# |   |   |   |--- class: 3
# |--- feature_2 >  0.50
# |   |--- feature_0 <= 55.50
# |   |   |--- feature_4 <= 156.50
# |   |   |   |--- class: 0
# |   |   |--- feature_4 >  156.50
# |   |   |   |--- class: 0
# |   |--- feature_0 >  55.50
# |   |   |--- feature_9 <= 1.95
# |   |   |   |--- class: 0
# |   |   |--- feature_9 >  1.95
# |   |   |   |--- class: 0

# %%
model.feature_importances_
# Out:
# array([0.27083797, 0.32765895, 0.19798492, 0.20351816])

# %%
import pandas as pd
feature_imp = pd.Series(model.feature_importances_,index=fn).sort_values(ascending=False)
feature_imp
# Out:
# cp          0.525732
# age         0.159774
# chol        0.157291
# oldpeak     0.157203
# trestbps    0.000000
# sex         0.000000
# restecg     0.000000
# fbs         0.000000
# thalach     0.000000
# exang       0.000000
# slope       0.000000
# ca          0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %% [markdown]
# chest pain #cp  is the import feature among all the features

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test, y_pred)
confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.70      0.70        76
#            1       0.42      0.71      0.53        55
#            2       0.00      0.00      0.00        22
#            3       0.20      0.13      0.16        23
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.52       182
#    macro avg       0.27      0.31      0.28       182
# weighted avg       0.45      0.52      0.47       182
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.521978021978022

# %% [markdown]
# #Hyper para tunning to improve Accuracy

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='gini', max_depth= 3 )
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test, y_pred)
confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.68      0.73        76
#            1       0.37      0.49      0.42        55
#            2       0.21      0.14      0.17        22
#            3       0.32      0.39      0.35        23
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.50       182
#    macro avg       0.34      0.34      0.33       182
# weighted avg       0.50      0.50      0.50       182
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5

# %% [markdown]
# #changing NO.of depths

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='gini', max_depth= 4 )
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test, y_pred)
confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.93      0.74        76
#            1       0.59      0.36      0.45        55
#            2       0.19      0.27      0.22        22
#            3       0.00      0.00      0.00        23
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.53       182
#    macro avg       0.28      0.31      0.28       182
# weighted avg       0.46      0.53      0.47       182
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.532967032967033

# %% [markdown]
# #change to entropy with Max depth 4

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', max_depth= 5 )
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test, y_pred)
confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76        76
#            1       0.53      0.42      0.47        55
#            2       0.21      0.32      0.25        22
#            3       0.27      0.13      0.18        23
#            4       0.33      0.17      0.22         6
#
#     accuracy                           0.54       182
#    macro avg       0.41      0.38      0.38       182
# weighted avg       0.52      0.54      0.52       182

# %% [markdown]
# #as we came to know the CP, age, chol, oldpeak is the import feature we will ignore other features that are not important by droping the columns like

# %%
x.columns
# Out:
# Index(['age', 'cp', 'chol', 'oldpeak'], dtype='object')

# %%
x.drop(columns=['sex', 'trestbps', 'fbs', 'restecg',  'exang', 'slope'], inplace=True)

# %%
x.head()
# Out:
#    age  cp  chol  thalch  oldpeak  thal
# 0   63   3   233     150      2.3     0
# 1   41   1   203     132      0.0     0
# 2   57   0   192     148      0.4     0
# 3   52   3   186     190      0.0     0
# 4   57   0   201     126      1.5     0

# %%
x.drop(columns=['thalch'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-233-2103ace5a311> in <cell line: 0>()
# ----> 1 x.drop(columns=['thalch'], inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['thalch'] not found in axis"

# %%
x.head()
# Out:
#    age  cp  chol  oldpeak  thal
# 0   63   3   233      2.3     0
# 1   41   1   203      0.0     0
# 2   57   0   192      0.4     0
# 3   52   3   186      0.0     0
# 4   57   0   201      1.5     0

# %%
x.drop(columns=['thal'], inplace=True)

# %% [markdown]
# #now lets train the thid data using this features and find the accuracy

# %%
x
# Out:
#      age  cp  chol   oldpeak
# 0     63   3   233  2.300000
# 1     41   1   203  0.000000
# 2     57   0   192  0.400000
# 3     52   3   186  0.000000
# 4     57   0   201  1.500000
# ..   ...  ..   ...       ...
# 903   53   0     0  1.500000
# 904   62   0   170  3.000000
# 905   56   2     0  2.500000
# 906   56   2   208  0.891253
# 907   57   0   277  0.891253
#
# [908 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 903    4
# 904    4
# 905    4
# 906    4
# 907    4
# Name: num, Length: 908, dtype: int64

# %%
from sklearn.model_selection  import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', max_depth= 5 )
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[1] <= 0.5\nentropy = 1.917\nsamples = 726\nvalue = [323.0, 210.0, 87.0, 84.0, 22.0]'),
#  Text(0.25, 0.75, 'x[3] <= 1.75\nentropy = 2.08\nsamples = 388\nvalue = [80.0, 155.0, 73.0, 62.0, 18.0]'),
#  Text(0.375, 0.8333333333333333, 'True  '),
#  Text(0.125, 0.5833333333333334, 'x[2] <= 42.5\nentropy = 1.984\nsamples = 271\nvalue = [74, 112, 44, 33, 8]'),
#  Text(0.0625, 0.4166666666666667, 'x[0] <= 58.5\nentropy = 2.025\nsamples = 77\nvalue = [6.0, 30.0, 20.0, 17.0, 4.0]'),
#  Text(0.03125, 0.25, 'x[0] <= 50.5\nentropy = 1.948\nsamples = 46\nvalue = [2, 17, 17, 6, 4]'),
#  Text(0.015625, 0.08333333333333333, 'entropy = 1.72\nsamples = 20\nvalue = [1, 9, 6, 4, 0]'),
#  Text(0.046875, 0.08333333333333333, 'entropy = 1.929\nsamples = 26\nvalue = [1, 8, 11, 2, 4]'),
#  Text(0.09375, 0.25, 'x[0] <= 66.0\nentropy = 1.763\nsamples = 31\nvalue = [4, 13, 3, 11, 0]'),
#  Text(0.078125, 0.08333333333333333, 'entropy = 1.713\nsamples = 28\nvalue = [4, 13, 2, 9, 0]'),
#  Text(0.109375, 0.08333333333333333, 'entropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2, 0]'),
#  Text(0.1875, 0.4166666666666667, 'x[0] <= 58.5\nentropy = 1.841\nsamples = 194\nvalue = [68, 82, 24, 16, 4]'),
#  Text(0.15625, 0.25, 'x[3] <= 0.7\nentropy = 1.531\nsamples = 132\nvalue = [55, 63, 5, 7, 2]'),
#  Text(0.140625, 0.08333333333333333, 'entropy = 1.349\nsamples = 69\nvalue = [38, 26, 2, 3, 0]'),
#  Text(0.171875, 0.08333333333333333, 'entropy = 1.581\nsamples = 63\nvalue = [17, 37, 3, 4, 2]'),
#  Text(0.21875, 0.25, 'x[0] <= 63.5\nentropy = 2.082\nsamples = 62\nvalue = [13, 19, 19, 9, 2]'),
#  Text(0.203125, 0.08333333333333333, 'entropy = 1.802\nsamples = 33\nvalue = [7, 15, 8, 3, 0]'),
#  Text(0.234375, 0.08333333333333333, 'entropy = 2.131\nsamples = 29\nvalue = [6, 4, 11, 6, 2]'),
#  Text(0.375, 0.5833333333333334, 'x[0] <= 58.5\nentropy = 2.051\nsamples = 117\nvalue = [6, 43, 29, 29, 10]'),
#  Text(0.3125, 0.4166666666666667, 'x[2] <= 58.5\nentropy = 1.804\nsamples = 69\nvalue = [3, 36, 14, 13, 3]'),
#  Text(0.28125, 0.25, 'x[3] <= 1.9\nentropy = 1.771\nsamples = 10\nvalue = [1, 1, 6, 1, 1]'),
#  Text(0.265625, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.296875, 0.08333333333333333, 'entropy = 1.447\nsamples = 9\nvalue = [1, 0, 6, 1, 1]'),
#  Text(0.34375, 0.25, 'x[2] <= 304.5\nentropy = 1.636\nsamples = 59\nvalue = [2, 35, 8, 12, 2]'),
#  Text(0.328125, 0.08333333333333333, 'entropy = 1.456\nsamples = 45\nvalue = [2, 28, 2, 12, 1]'),
#  Text(0.359375, 0.08333333333333333, 'entropy = 1.296\nsamples = 14\nvalue = [0, 7, 6, 0, 1]'),
#  Text(0.4375, 0.4166666666666667, 'x[3] <= 2.2\nentropy = 2.113\nsamples = 48\nvalue = [3, 7, 15, 16, 7]'),
#  Text(0.40625, 0.25, 'x[0] <= 63.5\nentropy = 1.897\nsamples = 23\nvalue = [3, 5, 6, 9, 0]'),
#  Text(0.390625, 0.08333333333333333, 'entropy = 1.738\nsamples = 13\nvalue = [1, 2, 6, 4, 0]'),
#  Text(0.421875, 0.08333333333333333, 'entropy = 1.485\nsamples = 10\nvalue = [2, 3, 0, 5, 0]'),
#  Text(0.46875, 0.25, 'x[2] <= 165.0\nentropy = 1.851\nsamples = 25\nvalue = [0.0, 2.0, 9.0, 7.0, 7.0]'),
#  Text(0.453125, 0.08333333333333333, 'entropy = 0.971\nsamples = 5\nvalue = [0, 0, 2, 3, 0]'),
#  Text(0.484375, 0.08333333333333333, 'entropy = 1.857\nsamples = 20\nvalue = [0, 2, 7, 4, 7]'),
#  Text(0.75, 0.75, 'x[0] <= 55.5\nentropy = 1.291\nsamples = 338\nvalue = [243.0, 55.0, 14.0, 22.0, 4.0]'),
#  Text(0.625, 0.8333333333333333, '  False'),
#  Text(0.625, 0.5833333333333334, 'x[2] <= 156.5\nentropy = 0.85\nsamples = 212\nvalue = [175, 28, 1, 7, 1]'),
#  Text(0.5625, 0.4166666666666667, 'x[1] <= 2.5\nentropy = 1.708\nsamples = 22\nvalue = [9, 8, 1, 4, 0]'),
#  Text(0.53125, 0.25, 'x[0] <= 46.0\nentropy = 1.509\nsamples = 19\nvalue = [9, 6, 0, 4, 0]'),
#  Text(0.515625, 0.08333333333333333, 'entropy = 0.65\nsamples = 6\nvalue = [5, 1, 0, 0, 0]'),
#  Text(0.546875, 0.08333333333333333, 'entropy = 1.577\nsamples = 13\nvalue = [4, 5, 0, 4, 0]'),
#  Text(0.59375, 0.25, 'x[0] <= 41.5\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1, 0, 0]'),
#  Text(0.578125, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.609375, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.6875, 0.4166666666666667, 'x[3] <= 0.846\nentropy = 0.646\nsamples = 190\nvalue = [166, 20, 0, 3, 1]'),
#  Text(0.65625, 0.25, 'x[2] <= 219.5\nentropy = 0.389\nsamples = 144\nvalue = [133, 11, 0, 0, 0]'),
#  Text(0.640625, 0.08333333333333333, 'entropy = 0.0\nsamples = 54\nvalue = [54, 0, 0, 0, 0]'),
#  Text(0.671875, 0.08333333333333333, 'entropy = 0.536\nsamples = 90\nvalue = [79, 11, 0, 0, 0]'),
#  Text(0.71875, 0.25, 'x[3] <= 2.7\nentropy = 1.181\nsamples = 46\nvalue = [33, 9, 0, 3, 1]'),
#  Text(0.703125, 0.08333333333333333, 'entropy = 0.961\nsamples = 41\nvalue = [32, 6, 0, 3, 0]'),
#  Text(0.734375, 0.08333333333333333, 'entropy = 1.371\nsamples = 5\nvalue = [1, 3, 0, 0, 1]'),
#  Text(0.875, 0.5833333333333334, 'x[3] <= 1.95\nentropy = 1.788\nsamples = 126\nvalue = [68, 27, 13, 15, 3]'),
#  Text(0.8125, 0.4166666666666667, 'x[2] <= 63.0\nentropy = 1.564\nsamples = 108\nvalue = [64, 24, 9, 11, 0]'),
#  Text(0.78125, 0.25, 'x[0] <= 72.5\nentropy = 1.955\nsamples = 18\nvalue = [6, 4, 5, 3, 0]'),
#  Text(0.765625, 0.08333333333333333, 'entropy = 1.883\nsamples = 16\nvalue = [6, 2, 5, 3, 0]'),
#  Text(0.796875, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.84375, 0.25, 'x[2] <= 194.0\nentropy = 1.401\nsamples = 90\nvalue = [58.0, 20.0, 4.0, 8.0, 0.0]'),
#  Text(0.828125, 0.08333333333333333, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0, 0, 0, 0]'),
#  Text(0.859375, 0.08333333333333333, 'entropy = 1.481\nsamples = 81\nvalue = [49, 20, 4, 8, 0]'),
#  Text(0.9375, 0.4166666666666667, 'x[0] <= 58.5\nentropy = 2.308\nsamples = 18\nvalue = [4, 3, 4, 4, 3]'),
#  Text(0.90625, 0.25, 'x[3] <= 2.85\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 0, 1, 2]'),
#  Text(0.890625, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.921875, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.96875, 0.25, 'x[0] <= 66.5\nentropy = 2.206\nsamples = 15\nvalue = [4, 3, 4, 3, 1]'),
#  Text(0.953125, 0.08333333333333333, 'entropy = 1.846\nsamples = 10\nvalue = [4, 3, 2, 1, 0]'),
#  Text(0.984375, 0.08333333333333333, 'entropy = 1.522\nsamples = 5\nvalue = [0, 0, 2, 2, 1]')]

# %%
x.columns
# Out:
# Index(['age', 'cp', 'chol', 'oldpeak'], dtype='object')

# %%
fn = ['age', 'cp', 'chol', 'oldpeak']
cn = ['No heart attack', 'Stage 1', 'Stage 2', 'Stage 3', 'stage 4' ]
tree.plot_tree(model,
               feature_names = fn,
               class_names=cn,
               filled = True);

# %%
model.feature_importances_
# Out:
# array([0.27668086, 0.32765895, 0.19798492, 0.19767527])

# %%
import pandas as pd
feature_imp = pd.Series(model.feature_importances_,index=fn).sort_values(ascending=False)
feature_imp
# Out:
# cp         0.327659
# age        0.276681
# chol       0.197985
# oldpeak    0.197675
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', max_depth= 5, min_samples_split= 70)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test, y_pred)
confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.87      0.76        76
#            1       0.49      0.62      0.54        55
#            2       0.00      0.00      0.00        22
#            3       0.20      0.13      0.16        23
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.57       182
#    macro avg       0.27      0.32      0.29       182
# weighted avg       0.46      0.57      0.50       182
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.5659340659340659

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='gini', max_depth= 6, min_samples_split= 5)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy_score(y_test, y_pred)
confusion_matrix(y_test, y_pred)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.92      0.74        76
#            1       0.51      0.36      0.43        55
#            2       0.21      0.27      0.24        22
#            3       0.00      0.00      0.00        23
#            4       0.00      0.00      0.00         6
#
#     accuracy                           0.53       182
#    macro avg       0.27      0.31      0.28       182
# weighted avg       0.44      0.53      0.47       182
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
